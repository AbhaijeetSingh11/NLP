# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# After the data cleaning step where we put our data into a few standard formats, the next step is to take a look at the data and see if what we're looking at makes sense. Before applying any fancy algorithms, it's always important to explore the data first.
#
# When working with numerical data, some of the exploratory data analysis (EDA) techniques we can use include finding the average of the data set, the distribution of the data, the most common values, etc. The idea is the same when working with text data. We are going to find some more obvious patterns with EDA before identifying the hidden patterns with machines learning (ML) techniques. We are going to look at the following for each comedian:
#
# 1. **Most common words** - find these and create word clouds
# 2. **Size of vocabulary** - look number of unique words and also how quickly someone speaks
# 3. **Amount of profanity** - most common terms

# %% [markdown]
# ## Most Common Words

# %% [markdown]
# ### Analysis

# %%
import joblib
# Load the pickle file using joblib
data_dtm = joblib.load("data_dtm.pkl")

# %%
data = data_dtm.transpose()
data.head()
# Out:
#               ali  anthony  bill  bo  dave  hasan  jim  joe  john  louis  \
# able            2        0     1   0     0      1    1    2     3      1
# accent          0        1     0   0     0      0    4    1     1      0
# accident        1        0     0   2     0      0    0    0     0      1
# accidentally    1        1     2   1     0      0    0    1     0      0
# act like        1        0     2   0     1      1    4    0     0      0
#
#               mike  ricky
# able             0      2
# accent           0      0
# accident        15      0
# accidentally     0      0
# act like         0      0

# %%
# Find the top 30 words said by each comedian
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'ali': [('wanna', 21),
#   ('husband', 20),
#   ('pregnant', 15),
#   ('scared', 10),
#   ('toilet', 9),
#   ('mom', 9),
#   ('dont wanna', 9),
#   ('body', 8),
#   ('smell', 7),
#   ('ladies', 6),
#   ('married', 6),
#   ('pussy', 5),
#   ('seven', 5),
#   ('months', 5),
#   ('doctor', 5),
#   ('means', 5),
#   ('got married', 5),
#   ('paper', 5),
#   ('huge', 5),
#   ('business', 4),
#   ('push', 4),
#   ('trap', 4),
#   ('chinese', 4),
#   ('homeless', 4),
#   ('um', 4),
#   ('time like', 4),
#   ('playing', 4),
#   ('hole', 4),
#   ('park', 4),
#   ('blow', 4)],
#  'anthony': [('joke', 34),
#   ('grandma', 18),
#   ('mad', 14),
#   ('mom', 11),
#   ('san', 11),
#   ('today', 9),
#   ('francisco', 8),
#   ('loved', 8),
#   ('san francisco', 8),
#   ('comedian', 7),
#   ('card', 7),
#   ('college', 7),
#   ('tragedy', 6),
#   ('ive got', 6),
#   ('death', 6),
#   ('shows', 6),
#   ('gun', 6),
#   ('forget', 5),
#   ('worry', 5),
#   ('talked', 5),
#   ('wanna', 5),
#   ('laugh', 5),
#   ('died', 5),
#   ('killed', 5),
#   ('fuckin', 4),
#   ('soon', 4),
#   ('asked', 4),
#   ('tonight', 4),
#   ('thats good', 4),
#   ('im good', 4)],
#  'bill': [('gun', 19),
#   ('jesus', 14),
#   ('trouble', 11),
#   ('sudden', 11),
#   ('religion', 11),
#   ('hit', 11),
#   ('bring', 10),
#   ('fuckin', 10),
#   ('anybody', 9),
#   ('goddamn', 9),
#   ('dont understand', 9),
#   ('wife', 9),
#   ('figure', 8),
#   ('whoa', 8),
#   ('basically', 8),
#   ('honest', 7),
#   ('shot', 7),
#   ('like right', 7),
#   ('hug', 7),
#   ('joke', 7),
#   ('hang', 6),
#   ('know just', 6),
#   ('thank thank', 6),
#   ('right im', 6),
#   ('couch', 6),
#   ('ya', 6),
#   ('somebody', 6),
#   ('turned', 6),
#   ('stories', 6),
#   ('finally', 6)],
#  'bo': [('repeat', 23),
#   ('eye', 22),
#   ('um', 15),
#   ('sad', 14),
#   ('brain', 13),
#   ('song', 12),
#   ('deep', 9),
#   ('yeah yeah', 8),
#   ('magic', 8),
#   ('joke', 6),
#   ('meant', 6),
#   ('idiot', 6),
#   ('pussy', 6),
#   ('pretty', 6),
#   ('book', 6),
#   ('changed', 5),
#   ('wanna', 5),
#   ('father', 5),
#   ('heart', 5),
#   ('poem', 5),
#   ('rape', 4),
#   ('porn', 4),
#   ('kept', 4),
#   ('dance', 4),
#   ('note', 4),
#   ('jesus', 4),
#   ('sort', 4),
#   ('shouldnt', 4),
#   ('feeling', 4),
#   ('special', 4)],
#  'dave': [('young', 10),
#   ('mad', 10),
#   ('motherfucker', 10),
#   ('american', 9),
#   ('wife', 9),
#   ('mr', 8),
#   ('havent', 7),
#   ('brother', 6),
#   ('generation', 6),
#   ('shut fuck', 6),
#   ('game', 6),
#   ('crowd', 6),
#   ('rape', 6),
#   ('war', 6),
#   ('states', 6),
#   ('tough', 6),
#   ('fight', 5),
#   ('kick', 5),
#   ('dinner', 5),
#   ('forget', 5),
#   ('know mean', 5),
#   ('la', 5),
#   ('television', 5),
#   ('suddenly', 5),
#   ('age', 5),
#   ('good night', 5),
#   ('green', 5),
#   ('stood', 5),
#   ('like man', 5),
#   ('mind', 5)],
#  'hasan': [('mom', 25),
#   ('brown', 21),
#   ('shes like', 19),
#   ('bike', 14),
#   ('york', 12),
#   ('birthday', 12),
#   ('new york', 12),
#   ('married', 10),
#   ('outside', 9),
#   ('la', 8),
#   ('country', 8),
#   ('past', 8),
#   ('open', 7),
#   ('class', 7),
#   ('father', 7),
#   ('blue', 6),
#   ('ive got', 6),
#   ('facebook', 6),
#   ('crying', 6),
#   ('clear', 6),
#   ('brother', 6),
#   ('box', 6),
#   ('color', 6),
#   ('youre going', 6),
#   ('hey man', 6),
#   ('proud', 6),
#   ('late', 6),
#   ('dreams', 5),
#   ('walks', 5),
#   ('table', 5)],
#  'jim': [('guns', 27),
#   ('girlfriend', 17),
#   ('gun', 16),
#   ('business', 13),
#   ('south', 13),
#   ('class', 13),
#   ('girls', 12),
#   ('like fucking', 11),
#   ('ticket', 10),
#   ('mothers', 9),
#   ('bring', 9),
#   ('cunts', 9),
#   ('wanna', 9),
#   ('right im', 9),
#   ('um', 9),
#   ('americans', 7),
#   ('agree', 7),
#   ('group', 7),
#   ('porn', 7),
#   ('important', 6),
#   ('soon', 6),
#   ('earth', 6),
#   ('bag', 6),
#   ('enjoy', 6),
#   ('appreciate', 6),
#   ('youre fucking', 6),
#   ('security', 6),
#   ('answer', 6),
#   ('im saying', 6),
#   ('girlfriends', 6)],
#  'joe': [('wanna', 15),
#   ('stupid', 13),
#   ('texas', 12),
#   ('bullshit', 11),
#   ('smart', 10),
#   ('fuck fuck', 9),
#   ('dudes', 8),
#   ('religion', 8),
#   ('earth', 8),
#   ('president', 8),
#   ('santa', 8),
#   ('mom', 7),
#   ('lived', 7),
#   ('figure', 7),
#   ('exactly', 7),
#   ('killed', 6),
#   ('sexist', 6),
#   ('means', 6),
#   ('million', 6),
#   ('anybody', 6),
#   ('suck', 6),
#   ('just start', 6),
#   ('definitely', 6),
#   ('dumb', 5),
#   ('office', 5),
#   ('hang', 5),
#   ('sucks', 5),
#   ('possible', 5),
#   ('guard', 5),
#   ('california', 5)],
#  'john': [('mom', 22),
#   ('wife', 18),
#   ('john', 12),
#   ('president', 12),
#   ('past', 11),
#   ('dinner', 11),
#   ('mr', 9),
#   ('office', 9),
#   ('ah', 8),
#   ('boy', 8),
#   ('married', 8),
#   ('church', 7),
#   ('wanna', 7),
#   ('new york', 7),
#   ('college', 7),
#   ('loved', 7),
#   ('milk', 7),
#   ('york', 7),
#   ('catholic', 6),
#   ('wed', 6),
#   ('bought', 6),
#   ('best friend', 6),
#   ('named', 6),
#   ('penis', 6),
#   ('brother', 5),
#   ('drugs', 5),
#   ('list', 5),
#   ('sound', 5),
#   ('sam', 5),
#   ('foryears', 5)],
#  'louis': [('ha', 13),
#   ('date', 12),
#   ('food', 11),
#   ('worst', 11),
#   ('young', 8),
#   ('pretty', 7),
#   ('building', 7),
#   ('im sitting', 7),
#   ('ends', 7),
#   ('deal', 6),
#   ('courage', 6),
#   ('socks', 6),
#   ('fish', 5),
#   ('means', 5),
#   ('piece', 5),
#   ('dies', 5),
#   ('touch', 5),
#   ('somebody', 5),
#   ('thoughts', 5),
#   ('book', 5),
#   ('history', 5),
#   ('legs', 4),
#   ('marriage', 4),
#   ('bag', 4),
#   ('facebook', 4),
#   ('touched', 4),
#   ('stay', 4),
#   ('know cause', 4),
#   ('usually', 4),
#   ('new york', 4)],
#  'mike': [('accident', 15),
#   ('argument', 11),
#   ('married', 10),
#   ('club', 10),
#   ('marriage', 9),
#   ('sort', 9),
#   ('idea', 9),
#   ('flight', 9),
#   ('ride', 8),
#   ('texas', 8),
#   ('relationship', 8),
#   ('pretty', 8),
#   ('just dont', 8),
#   ('win', 7),
#   ('sounds', 7),
#   ('id like', 7),
#   ('youre right', 7),
#   ('hours', 6),
#   ('late', 6),
#   ('werent', 6),
#   ('hit', 6),
#   ('calling', 6),
#   ('think thats', 6),
#   ('boyfriend', 6),
#   ('officer', 6),
#   ('fall', 6),
#   ('plan', 6),
#   ('class', 6),
#   ('dont believe', 6),
#   ('im sure', 6)],
#  'ricky': [('joke', 31),
#   ('nuts', 18),
#   ('jenner', 16),
#   ('rape', 14),
#   ('doctor', 12),
#   ('ive got', 12),
#   ('born', 11),
#   ('bring', 10),
#   ('sent', 10),
#   ('boy', 8),
#   ('years ago', 8),
#   ('ridiculous', 8),
#   ('laugh', 8),
#   ('shed', 8),
#   ('plane', 7),
#   ('news', 7),
#   ('laughing', 7),
#   ('things like', 7),
#   ('yeah yeah', 6),
#   ('wanna', 6),
#   ('worry', 6),
#   ('worse', 6),
#   ('obviously', 6),
#   ('near', 6),
#   ('golden', 6),
#   ('everyones', 6),
#   ('hair', 6),
#   ('lived', 6),
#   ('early', 5),
#   ('loves', 5)]}

# %%
# Print the top 15 words said by each comedian
for comedian, top_words in top_dict.items():
    print(comedian)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# ali
# wanna, husband, pregnant, scared, toilet, mom, dont wanna, body, smell, ladies, married, pussy, seven, months
# ---
# anthony
# joke, grandma, mad, mom, san, today, francisco, loved, san francisco, comedian, card, college, tragedy, ive got
# ---
# bill
# gun, jesus, trouble, sudden, religion, hit, bring, fuckin, anybody, goddamn, dont understand, wife, figure, whoa
# ---
# bo
# repeat, eye, um, sad, brain, song, deep, yeah yeah, magic, joke, meant, idiot, pussy, pretty
# ---
# dave
# young, mad, motherfucker, american, wife, mr, havent, brother, generation, shut fuck, game, crowd, rape, war
# ---
# hasan
# mom, brown, shes like, bike, york, birthday, new york, married, outside, la, country, past, open, class
# ---
# jim
# guns, girlfriend, gun, business, south, class, girls, like fucking, ticket, mothers, bring, cunts, wanna, right im
# ---
# joe
# wanna, stupid, texas, bullshit, smart, fuck fuck, dudes, religion, earth, president, santa, mom, lived, figure
# ---
# john
# mom, wife, john, president, past, dinner, mr, office, ah, boy, married, church, wanna, new york
# ---
# louis
# ha, date, food, worst, young, pretty, building, im sitting, ends, deal, courage, socks, fish, means
# ---
# mike
# accident, argument, married, club, marriage, sort, idea, flight, ride, texas, relationship, pretty, just dont, win
# ---
# ricky
# joke, nuts, jenner, rape, doctor, ive got, born, bring, sent, boy, years ago, ridiculous, laugh, shed
# ---

# %% [markdown]
# **NOTE:** At this point, we could go on and create word clouds. However, by looking at these top words, you can see that some of them have very little meaning and could be added to a stop words list, so let's do just that.

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for comedian in data.columns:
    top = [word for (word, count) in top_dict[comedian]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['wanna',
#  'husband',
#  'pregnant',
#  'scared',
#  'toilet',
#  'mom',
#  'dont wanna',
#  'body',
#  'smell',
#  'ladies',
#  'married',
#  'pussy',
#  'seven',
#  'months',
#  'doctor',
#  'means',
#  'got married',
#  'paper',
#  'huge',
#  'business',
#  'push',
#  'trap',
#  'chinese',
#  'homeless',
#  'um',
#  'time like',
#  'playing',
#  'hole',
#  'park',
#  'blow',
#  'joke',
#  'grandma',
#  'mad',
#  'mom',
#  'san',
#  'today',
#  'francisco',
#  'loved',
#  'san francisco',
#  'comedian',
#  'card',
#  'college',
#  'tragedy',
#  'ive got',
#  'death',
#  'shows',
#  'gun',
#  'forget',
#  'worry',
#  'talked',
#  'wanna',
#  'laugh',
#  'died',
#  'killed',
#  'fuckin',
#  'soon',
#  'asked',
#  'tonight',
#  'thats good',
#  'im good',
#  'gun',
#  'jesus',
#  'trouble',
#  'sudden',
#  'religion',
#  'hit',
#  'bring',
#  'fuckin',
#  'anybody',
#  'goddamn',
#  'dont understand',
#  'wife',
#  'figure',
#  'whoa',
#  'basically',
#  'honest',
#  'shot',
#  'like right',
#  'hug',
#  'joke',
#  'hang',
#  'know just',
#  'thank thank',
#  'right im',
#  'couch',
#  'ya',
#  'somebody',
#  'turned',
#  'stories',
#  'finally',
#  'repeat',
#  'eye',
#  'um',
#  'sad',
#  'brain',
#  'song',
#  'deep',
#  'yeah yeah',
#  'magic',
#  'joke',
#  'meant',
#  'idiot',
#  'pussy',
#  'pretty',
#  'book',
#  'changed',
#  'wanna',
#  'father',
#  'heart',
#  'poem',
#  'rape',
#  'porn',
#  'kept',
#  'dance',
#  'note',
#  'jesus',
#  'sort',
#  'shouldnt',
#  'feeling',
#  'special',
#  'young',
#  'mad',
#  'motherfucker',
#  'american',
#  'wife',
#  'mr',
#  'havent',
#  'brother',
#  'generation',
#  'shut fuck',
#  'game',
#  'crowd',
#  'rape',
#  'war',
#  'states',
#  'tough',
#  'fight',
#  'kick',
#  'dinner',
#  'forget',
#  'know mean',
#  'la',
#  'television',
#  'suddenly',
#  'age',
#  'good night',
#  'green',
#  'stood',
#  'like man',
#  'mind',
#  'mom',
#  'brown',
#  'shes like',
#  'bike',
#  'york',
#  'birthday',
#  'new york',
#  'married',
#  'outside',
#  'la',
#  'country',
#  'past',
#  'open',
#  'class',
#  'father',
#  'blue',
#  'ive got',
#  'facebook',
#  'crying',
#  'clear',
#  'brother',
#  'box',
#  'color',
#  'youre going',
#  'hey man',
#  'proud',
#  'late',
#  'dreams',
#  'walks',
#  'table',
#  'guns',
#  'girlfriend',
#  'gun',
#  'business',
#  'south',
#  'class',
#  'girls',
#  'like fucking',
#  'ticket',
#  'mothers',
#  'bring',
#  'cunts',
#  'wanna',
#  'right im',
#  'um',
#  'americans',
#  'agree',
#  'group',
#  'porn',
#  'important',
#  'soon',
#  'earth',
#  'bag',
#  'enjoy',
#  'appreciate',
#  'youre fucking',
#  'security',
#  'answer',
#  'im saying',
#  'girlfriends',
#  'wanna',
#  'stupid',
#  'texas',
#  'bullshit',
#  'smart',
#  'fuck fuck',
#  'dudes',
#  'religion',
#  'earth',
#  'president',
#  'santa',
#  'mom',
#  'lived',
#  'figure',
#  'exactly',
#  'killed',
#  'sexist',
#  'means',
#  'million',
#  'anybody',
#  'suck',
#  'just start',
#  'definitely',
#  'dumb',
#  'office',
#  'hang',
#  'sucks',
#  'possible',
#  'guard',
#  'california',
#  'mom',
#  'wife',
#  'john',
#  'president',
#  'past',
#  'dinner',
#  'mr',
#  'office',
#  'ah',
#  'boy',
#  'married',
#  'church',
#  'wanna',
#  'new york',
#  'college',
#  'loved',
#  'milk',
#  'york',
#  'catholic',
#  'wed',
#  'bought',
#  'best friend',
#  'named',
#  'penis',
#  'brother',
#  'drugs',
#  'list',
#  'sound',
#  'sam',
#  'foryears',
#  'ha',
#  'date',
#  'food',
#  'worst',
#  'young',
#  'pretty',
#  'building',
#  'im sitting',
#  'ends',
#  'deal',
#  'courage',
#  'socks',
#  'fish',
#  'means',
#  'piece',
#  'dies',
#  'touch',
#  'somebody',
#  'thoughts',
#  'book',
#  'history',
#  'legs',
#  'marriage',
#  'bag',
#  'facebook',
#  'touched',
#  'stay',
#  'know cause',
#  'usually',
#  'new york',
#  'accident',
#  'argument',
#  'married',
#  'club',
#  'marriage',
#  'sort',
#  'idea',
#  'flight',
#  'ride',
#  'texas',
#  'relationship',
#  'pretty',
#  'just dont',
#  'win',
#  'sounds',
#  'id like',
#  'youre right',
#  'hours',
#  'late',
#  'werent',
#  'hit',
#  'calling',
#  'think thats',
#  'boyfriend',
#  'officer',
#  'fall',
#  'plan',
#  'class',
#  'dont believe',
#  'im sure',
#  'joke',
#  'nuts',
#  'jenner',
#  'rape',
#  'doctor',
#  'ive got',
#  'born',
#  'bring',
#  'sent',
#  'boy',
#  'years ago',
#  'ridiculous',
#  'laugh',
#  'shed',
#  'plane',
#  'news',
#  'laughing',
#  'things like',
#  'yeah yeah',
#  'wanna',
#  'worry',
#  'worse',
#  'obviously',
#  'near',
#  'golden',
#  'everyones',
#  'hair',
#  'lived',
#  'early',
#  'loves']

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('wanna', 7),
#  ('mom', 5),
#  ('married', 4),
#  ('joke', 4),
#  ('means', 3),
#  ('um', 3),
#  ('ive got', 3),
#  ('gun', 3),
#  ('bring', 3),
#  ('wife', 3),
#  ('pretty', 3),
#  ('rape', 3),
#  ('brother', 3),
#  ('new york', 3),
#  ('class', 3),
#  ('pussy', 2),
#  ('doctor', 2),
#  ('business', 2),
#  ('mad', 2),
#  ('loved', 2),
#  ('college', 2),
#  ('forget', 2),
#  ('worry', 2),
#  ('laugh', 2),
#  ('killed', 2),
#  ('fuckin', 2),
#  ('soon', 2),
#  ('jesus', 2),
#  ('religion', 2),
#  ('hit', 2),
#  ('anybody', 2),
#  ('figure', 2),
#  ('hang', 2),
#  ('right im', 2),
#  ('somebody', 2),
#  ('yeah yeah', 2),
#  ('book', 2),
#  ('father', 2),
#  ('porn', 2),
#  ('sort', 2),
#  ('young', 2),
#  ('mr', 2),
#  ('dinner', 2),
#  ('la', 2),
#  ('york', 2),
#  ('past', 2),
#  ('facebook', 2),
#  ('late', 2),
#  ('earth', 2),
#  ('bag', 2),
#  ('texas', 2),
#  ('president', 2),
#  ('lived', 2),
#  ('office', 2),
#  ('boy', 2),
#  ('marriage', 2),
#  ('husband', 1),
#  ('pregnant', 1),
#  ('scared', 1),
#  ('toilet', 1),
#  ('dont wanna', 1),
#  ('body', 1),
#  ('smell', 1),
#  ('ladies', 1),
#  ('seven', 1),
#  ('months', 1),
#  ('got married', 1),
#  ('paper', 1),
#  ('huge', 1),
#  ('push', 1),
#  ('trap', 1),
#  ('chinese', 1),
#  ('homeless', 1),
#  ('time like', 1),
#  ('playing', 1),
#  ('hole', 1),
#  ('park', 1),
#  ('blow', 1),
#  ('grandma', 1),
#  ('san', 1),
#  ('today', 1),
#  ('francisco', 1),
#  ('san francisco', 1),
#  ('comedian', 1),
#  ('card', 1),
#  ('tragedy', 1),
#  ('death', 1),
#  ('shows', 1),
#  ('talked', 1),
#  ('died', 1),
#  ('asked', 1),
#  ('tonight', 1),
#  ('thats good', 1),
#  ('im good', 1),
#  ('trouble', 1),
#  ('sudden', 1),
#  ('goddamn', 1),
#  ('dont understand', 1),
#  ('whoa', 1),
#  ('basically', 1),
#  ('honest', 1),
#  ('shot', 1),
#  ('like right', 1),
#  ('hug', 1),
#  ('know just', 1),
#  ('thank thank', 1),
#  ('couch', 1),
#  ('ya', 1),
#  ('turned', 1),
#  ('stories', 1),
#  ('finally', 1),
#  ('repeat', 1),
#  ('eye', 1),
#  ('sad', 1),
#  ('brain', 1),
#  ('song', 1),
#  ('deep', 1),
#  ('magic', 1),
#  ('meant', 1),
#  ('idiot', 1),
#  ('changed', 1),
#  ('heart', 1),
#  ('poem', 1),
#  ('kept', 1),
#  ('dance', 1),
#  ('note', 1),
#  ('shouldnt', 1),
#  ('feeling', 1),
#  ('special', 1),
#  ('motherfucker', 1),
#  ('american', 1),
#  ('havent', 1),
#  ('generation', 1),
#  ('shut fuck', 1),
#  ('game', 1),
#  ('crowd', 1),
#  ('war', 1),
#  ('states', 1),
#  ('tough', 1),
#  ('fight', 1),
#  ('kick', 1),
#  ('know mean', 1),
#  ('television', 1),
#  ('suddenly', 1),
#  ('age', 1),
#  ('good night', 1),
#  ('green', 1),
#  ('stood', 1),
#  ('like man', 1),
#  ('mind', 1),
#  ('brown', 1),
#  ('shes like', 1),
#  ('bike', 1),
#  ('birthday', 1),
#  ('outside', 1),
#  ('country', 1),
#  ('open', 1),
#  ('blue', 1),
#  ('crying', 1),
#  ('clear', 1),
#  ('box', 1),
#  ('color', 1),
#  ('youre going', 1),
#  ('hey man', 1),
#  ('proud', 1),
#  ('dreams', 1),
#  ('walks', 1),
#  ('table', 1),
#  ('guns', 1),
#  ('girlfriend', 1),
#  ('south', 1),
#  ('girls', 1),
#  ('like fucking', 1),
#  ('ticket', 1),
#  ('mothers', 1),
#  ('cunts', 1),
#  ('americans', 1),
#  ('agree', 1),
#  ('group', 1),
#  ('important', 1),
#  ('enjoy', 1),
#  ('appreciate', 1),
#  ('youre fucking', 1),
#  ('security', 1),
#  ('answer', 1),
#  ('im saying', 1),
#  ('girlfriends', 1),
#  ('stupid', 1),
#  ('bullshit', 1),
#  ('smart', 1),
#  ('fuck fuck', 1),
#  ('dudes', 1),
#  ('santa', 1),
#  ('exactly', 1),
#  ('sexist', 1),
#  ('million', 1),
#  ('suck', 1),
#  ('just start', 1),
#  ('definitely', 1),
#  ('dumb', 1),
#  ('sucks', 1),
#  ('possible', 1),
#  ('guard', 1),
#  ('california', 1),
#  ('john', 1),
#  ('ah', 1),
#  ('church', 1),
#  ('milk', 1),
#  ('catholic', 1),
#  ('wed', 1),
#  ('bought', 1),
#  ('best friend', 1),
#  ('named', 1),
#  ('penis', 1),
#  ('drugs', 1),
#  ('list', 1),
#  ('sound', 1),
#  ('sam', 1),
#  ('foryears', 1),
#  ('ha', 1),
#  ('date', 1),
#  ('food', 1),
#  ('worst', 1),
#  ('building', 1),
#  ('im sitting', 1),
#  ('ends', 1),
#  ('deal', 1),
#  ('courage', 1),
#  ('socks', 1),
#  ('fish', 1),
#  ('piece', 1),
#  ('dies', 1),
#  ('touch', 1),
#  ('thoughts', 1),
#  ('history', 1),
#  ('legs', 1),
#  ('touched', 1),
#  ('stay', 1),
#  ('know cause', 1),
#  ('usually', 1),
#  ('accident', 1),
#  ('argument', 1),
#  ('club', 1),
#  ('idea', 1),
#  ('flight', 1),
#  ('ride', 1),
#  ('relationship', 1),
#  ('just dont', 1),
#  ('win', 1),
#  ('sounds', 1),
#  ('id like', 1),
#  ('youre right', 1),
#  ('hours', 1),
#  ('werent', 1),
#  ('calling', 1),
#  ('think thats', 1),
#  ('boyfriend', 1),
#  ('officer', 1),
#  ('fall', 1),
#  ('plan', 1),
#  ('dont believe', 1),
#  ('im sure', 1),
#  ('nuts', 1),
#  ('jenner', 1),
#  ('born', 1),
#  ('sent', 1),
#  ('years ago', 1),
#  ('ridiculous', 1),
#  ('shed', 1),
#  ('plane', 1),
#  ('news', 1),
#  ('laughing', 1),
#  ('things like', 1),
#  ('worse', 1),
#  ('obviously', 1),
#  ('near', 1),
#  ('golden', 1),
#  ('everyones', 1),
#  ('hair', 1),
#  ('early', 1),
#  ('loves', 1)]

# %%
# If more than half of the comedians have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 2]
add_stop_words
# Out:
# ['wanna',
#  'mom',
#  'married',
#  'joke',
#  'means',
#  'um',
#  'ive got',
#  'gun',
#  'bring',
#  'wife',
#  'pretty',
#  'rape',
#  'brother',
#  'new york',
#  'class']

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
# Read in cleaned data
data_clean = joblib.load("mydata_clean.pkl")

# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)
stop_words = list(text.ENGLISH_STOP_WORDS.union(add_stop_words)) 

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_stop.index = data_clean.index

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")
# Out:
# C:\Users\CGDXK\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_extraction\text.py:406: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['got', 'ive', 'new', 'york'] not in stop_words.
#   warnings.warn(

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

full_names = ['Ali Wong', 'Anthony Jeselnik', 'Bill Burr', 'Bo Burnham', 'Dave Chappelle', 'Hasan Minhaj',
              'Jim Jefferies', 'Joe Rogan', 'John Mulaney', 'Louis C.K.', 'Mike Birbiglia', 'Ricky Gervais']

# Create subplots for each comedian
for index, comedian in enumerate(data.columns):
    wc.generate(data_clean.transcript[comedian])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(full_names[index])
    
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * Ali Wong says the s-word a lot and talks about her husband. I guess that's funny to me.
# * A lot of people use the F-word. Let's dig into that later.

# %% [markdown]
# ## Number of Words

# %% [markdown]
# ### Analysis

# %%
# Find the number of unique words that each comedian uses

# Identify the non-zero items in the document-term matrix, meaning that the word occurs at least once
unique_list = []
for comedian in data.columns:
    uniques = data[comedian].to_numpy().nonzero()[0].size
    unique_list.append(uniques)

# Create a new dataframe that contains this unique word count
data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['comedian', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words')
data_unique_sort
# Out:
#             comedian  unique_words
# 3         Bo Burnham           424
# 1   Anthony Jeselnik           443
# 9         Louis C.K.           473
# 0           Ali Wong           479
# 8       John Mulaney           542
# 4     Dave Chappelle           561
# 5       Hasan Minhaj           570
# 11     Ricky Gervais           573
# 10    Mike Birbiglia           592
# 7          Joe Rogan           605
# 6      Jim Jefferies           606
# 2          Bill Burr           681

# %%
# Calculate the words per minute of each comedian

# Find the total number of words that a comedian uses
total_list = []
for comedian in data.columns:
    totals = sum(data[comedian])
    total_list.append(totals)
    
# Comedy special run times from IMDB, in minutes
run_times = [60, 59, 80, 60, 67, 73, 77, 63, 62, 58, 76, 79]

# Let's add some columns to our dataframe
data_words['total_words'] = total_list
data_words['run_times'] = run_times
data_words['words_per_minute'] = data_words['total_words'] / data_words['run_times']

# Sort the dataframe by words per minute to see who talks the slowest and fastest
data_wpm_sort = data_words.sort_values(by='words_per_minute')
data_wpm_sort
# Out:
#             comedian  unique_words  total_words  run_times  words_per_minute
# 3         Bo Burnham           424          785         60         13.083333
# 1   Anthony Jeselnik           443          832         59         14.101695
# 0           Ali Wong           479          851         60         14.183333
# 9         Louis C.K.           473          849         58         14.637931
# 11     Ricky Gervais           573         1162         79         14.708861
# 4     Dave Chappelle           561         1012         67         15.104478
# 6      Jim Jefferies           606         1269         77         16.480519
# 5       Hasan Minhaj           570         1208         73         16.547945
# 10    Mike Birbiglia           592         1262         76         16.605263
# 8       John Mulaney           542         1058         62         17.064516
# 2          Bill Burr           681         1394         80         17.425000
# 7          Joe Rogan           605         1161         63         18.428571

# %%
# Let's plot our findings
import numpy as np

y_pos = np.arange(len(data_words))

plt.subplot(1, 2, 1)
plt.barh(y_pos, data_unique_sort.unique_words, align='center')
plt.yticks(y_pos, data_unique_sort.comedian)
plt.title('Number of Unique Words', fontsize=20)

plt.subplot(1, 2, 2)
plt.barh(y_pos, data_wpm_sort.words_per_minute, align='center')
plt.yticks(y_pos, data_wpm_sort.comedian)
plt.title('Number of Words Per Minute', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Vocabulary**
#    * Ricky Gervais (British comedy) and Bill Burr (podcast host) use a lot of words in their comedy
#    * Louis C.K. (self-depricating comedy) and Anthony Jeselnik (dark humor) have a smaller vocabulary
#
#
# * **Talking Speed**
#    * Joe Rogan (blue comedy) and Bill Burr (podcast host) talk fast
#    * Bo Burnham (musical comedy) and Anthony Jeselnik (dark humor) talk slow
#
# Ali Wong is somewhere in the middle in both cases. Nothing too interesting here.

# %% [markdown]
# ## Amount of Profanity

# %% [markdown]
# ### Analysis

# %%
# Earlier I said we'd revisit profanity. Let's take a look at the most common words again.
Counter(words).most_common()
# Out:
# [('wanna', 7),
#  ('mom', 5),
#  ('married', 4),
#  ('joke', 4),
#  ('means', 3),
#  ('um', 3),
#  ('ive got', 3),
#  ('gun', 3),
#  ('bring', 3),
#  ('wife', 3),
#  ('pretty', 3),
#  ('rape', 3),
#  ('brother', 3),
#  ('new york', 3),
#  ('class', 3),
#  ('pussy', 2),
#  ('doctor', 2),
#  ('business', 2),
#  ('mad', 2),
#  ('loved', 2),
#  ('college', 2),
#  ('forget', 2),
#  ('worry', 2),
#  ('laugh', 2),
#  ('killed', 2),
#  ('fuckin', 2),
#  ('soon', 2),
#  ('jesus', 2),
#  ('religion', 2),
#  ('hit', 2),
#  ('anybody', 2),
#  ('figure', 2),
#  ('hang', 2),
#  ('right im', 2),
#  ('somebody', 2),
#  ('yeah yeah', 2),
#  ('book', 2),
#  ('father', 2),
#  ('porn', 2),
#  ('sort', 2),
#  ('young', 2),
#  ('mr', 2),
#  ('dinner', 2),
#  ('la', 2),
#  ('york', 2),
#  ('past', 2),
#  ('facebook', 2),
#  ('late', 2),
#  ('earth', 2),
#  ('bag', 2),
#  ('texas', 2),
#  ('president', 2),
#  ('lived', 2),
#  ('office', 2),
#  ('boy', 2),
#  ('marriage', 2),
#  ('husband', 1),
#  ('pregnant', 1),
#  ('scared', 1),
#  ('toilet', 1),
#  ('dont wanna', 1),
#  ('body', 1),
#  ('smell', 1),
#  ('ladies', 1),
#  ('seven', 1),
#  ('months', 1),
#  ('got married', 1),
#  ('paper', 1),
#  ('huge', 1),
#  ('push', 1),
#  ('trap', 1),
#  ('chinese', 1),
#  ('homeless', 1),
#  ('time like', 1),
#  ('playing', 1),
#  ('hole', 1),
#  ('park', 1),
#  ('blow', 1),
#  ('grandma', 1),
#  ('san', 1),
#  ('today', 1),
#  ('francisco', 1),
#  ('san francisco', 1),
#  ('comedian', 1),
#  ('card', 1),
#  ('tragedy', 1),
#  ('death', 1),
#  ('shows', 1),
#  ('talked', 1),
#  ('died', 1),
#  ('asked', 1),
#  ('tonight', 1),
#  ('thats good', 1),
#  ('im good', 1),
#  ('trouble', 1),
#  ('sudden', 1),
#  ('goddamn', 1),
#  ('dont understand', 1),
#  ('whoa', 1),
#  ('basically', 1),
#  ('honest', 1),
#  ('shot', 1),
#  ('like right', 1),
#  ('hug', 1),
#  ('know just', 1),
#  ('thank thank', 1),
#  ('couch', 1),
#  ('ya', 1),
#  ('turned', 1),
#  ('stories', 1),
#  ('finally', 1),
#  ('repeat', 1),
#  ('eye', 1),
#  ('sad', 1),
#  ('brain', 1),
#  ('song', 1),
#  ('deep', 1),
#  ('magic', 1),
#  ('meant', 1),
#  ('idiot', 1),
#  ('changed', 1),
#  ('heart', 1),
#  ('poem', 1),
#  ('kept', 1),
#  ('dance', 1),
#  ('note', 1),
#  ('shouldnt', 1),
#  ('feeling', 1),
#  ('special', 1),
#  ('motherfucker', 1),
#  ('american', 1),
#  ('havent', 1),
#  ('generation', 1),
#  ('shut fuck', 1),
#  ('game', 1),
#  ('crowd', 1),
#  ('war', 1),
#  ('states', 1),
#  ('tough', 1),
#  ('fight', 1),
#  ('kick', 1),
#  ('know mean', 1),
#  ('television', 1),
#  ('suddenly', 1),
#  ('age', 1),
#  ('good night', 1),
#  ('green', 1),
#  ('stood', 1),
#  ('like man', 1),
#  ('mind', 1),
#  ('brown', 1),
#  ('shes like', 1),
#  ('bike', 1),
#  ('birthday', 1),
#  ('outside', 1),
#  ('country', 1),
#  ('open', 1),
#  ('blue', 1),
#  ('crying', 1),
#  ('clear', 1),
#  ('box', 1),
#  ('color', 1),
#  ('youre going', 1),
#  ('hey man', 1),
#  ('proud', 1),
#  ('dreams', 1),
#  ('walks', 1),
#  ('table', 1),
#  ('guns', 1),
#  ('girlfriend', 1),
#  ('south', 1),
#  ('girls', 1),
#  ('like fucking', 1),
#  ('ticket', 1),
#  ('mothers', 1),
#  ('cunts', 1),
#  ('americans', 1),
#  ('agree', 1),
#  ('group', 1),
#  ('important', 1),
#  ('enjoy', 1),
#  ('appreciate', 1),
#  ('youre fucking', 1),
#  ('security', 1),
#  ('answer', 1),
#  ('im saying', 1),
#  ('girlfriends', 1),
#  ('stupid', 1),
#  ('bullshit', 1),
#  ('smart', 1),
#  ('fuck fuck', 1),
#  ('dudes', 1),
#  ('santa', 1),
#  ('exactly', 1),
#  ('sexist', 1),
#  ('million', 1),
#  ('suck', 1),
#  ('just start', 1),
#  ('definitely', 1),
#  ('dumb', 1),
#  ('sucks', 1),
#  ('possible', 1),
#  ('guard', 1),
#  ('california', 1),
#  ('john', 1),
#  ('ah', 1),
#  ('church', 1),
#  ('milk', 1),
#  ('catholic', 1),
#  ('wed', 1),
#  ('bought', 1),
#  ('best friend', 1),
#  ('named', 1),
#  ('penis', 1),
#  ('drugs', 1),
#  ('list', 1),
#  ('sound', 1),
#  ('sam', 1),
#  ('foryears', 1),
#  ('ha', 1),
#  ('date', 1),
#  ('food', 1),
#  ('worst', 1),
#  ('building', 1),
#  ('im sitting', 1),
#  ('ends', 1),
#  ('deal', 1),
#  ('courage', 1),
#  ('socks', 1),
#  ('fish', 1),
#  ('piece', 1),
#  ('dies', 1),
#  ('touch', 1),
#  ('thoughts', 1),
#  ('history', 1),
#  ('legs', 1),
#  ('touched', 1),
#  ('stay', 1),
#  ('know cause', 1),
#  ('usually', 1),
#  ('accident', 1),
#  ('argument', 1),
#  ('club', 1),
#  ('idea', 1),
#  ('flight', 1),
#  ('ride', 1),
#  ('relationship', 1),
#  ('just dont', 1),
#  ('win', 1),
#  ('sounds', 1),
#  ('id like', 1),
#  ('youre right', 1),
#  ('hours', 1),
#  ('werent', 1),
#  ('calling', 1),
#  ('think thats', 1),
#  ('boyfriend', 1),
#  ('officer', 1),
#  ('fall', 1),
#  ('plan', 1),
#  ('dont believe', 1),
#  ('im sure', 1),
#  ('nuts', 1),
#  ('jenner', 1),
#  ('born', 1),
#  ('sent', 1),
#  ('years ago', 1),
#  ('ridiculous', 1),
#  ('shed', 1),
#  ('plane', 1),
#  ('news', 1),
#  ('laughing', 1),
#  ('things like', 1),
#  ('worse', 1),
#  ('obviously', 1),
#  ('near', 1),
#  ('golden', 1),
#  ('everyones', 1),
#  ('hair', 1),
#  ('early', 1),
#  ('loves', 1)]

# %%
# Let's isolate just these bad words
data_bad_words = data.transpose()[['rape', 'fuckin', 'jesus','pretty']]
data_profanity = pd.concat([data_bad_words.rape + data_bad_words.fuckin, data_bad_words.jesus+data_bad_words.pretty], axis=1)
data_profanity.columns = ['abuse_word', 'healthy_word']
data_profanity
# Out:
#          abuse_word  healthy_word
# ali               2             0
# anthony           4             1
# bill             11            16
# bo                4            10
# dave              6             0
# hasan             0             1
# jim               3             0
# joe               1             5
# john              1             3
# louis             0            11
# mike              0             8
# ricky            15             3

# %%
# Let's create a scatter plot of our findings
plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity.index):
    x = data_profanity.abuse_word.loc[comedian]
    y = data_profanity.healthy_word.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x+1.5, y+0.5, full_names[i], fontsize=10)
    plt.xlim(-5, 20)
    plt.ylim(-5,20) 
    
plt.title('Number of Bad Words Used in Routine', fontsize=20)
plt.xlabel('Number of Abuse Bombs', fontsize=15)
plt.ylabel('Number of Healthy Words', fontsize=15)

plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Averaging 2 F-Bombs Per Minute!** - I don't like too much swearing, especially the f-word, which is probably why I've never heard of Bill Bur, Joe Rogan and Jim Jefferies.
# * **Clean Humor** - It looks like profanity might be a good predictor of the type of comedy I like. Besides Ali Wong, my two other favorite comedians in this group are John Mulaney and Mike Birbiglia.

# %% [markdown]
# ## Side Note

# %% [markdown]
# What was our goal for the EDA portion of our journey? **To be able to take an initial look at our data and see if the results of some basic analysis made sense.**
#
# My conclusion - yes, it does, for a first pass. There are definitely some things that could be better cleaned up, such as adding more stop words or including bi-grams. But we can save that for another day. The results, especially the profanity findings, are interesting and make general sense, so we're going to move on.
#
# As a reminder, the data science process is an interative one. It's better to see some non-perfect but acceptable results to help you quickly decide whether your project is a dud or not, instead of having analysis paralysis and never delivering anything.
#
# **Alice's data science (and life) motto: Let go of perfectionism!**

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. What other word counts do you think would be interesting to compare instead of the f-word and s-word? Create a scatter plot comparing them.
